# %%
from sklearn.datasets import load_diabetes
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X, y = load_diabetes(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
reg = SGDRegressor(penalty='l2', max_iter=500, eta0=0.1, learning_rate='constant', alpha=0.001)

# %%
reg.fit(X_train, y_train)
# Out:
# SGDRegressor(alpha=0.001, eta0=0.1, learning_rate='constant', max_iter=500)

# %%
y_pred = reg.predict(X_test)
print(f"R2 score: {r2_score(y_test, y_pred)}")
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score: 0.422360790836496
# [  47.84104076 -160.12329735  368.68085558  273.55380011   -7.12516643
#   -58.21970104 -167.70918484  136.65943282  329.38091988   95.02343372]
# [141.96158435]

# %%
from sklearn.linear_model import Ridge

# %%
regg = Ridge(alpha = 0.001, max_iter=500, solver='sparse_cg')

# %%
regg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.001, max_iter=500, solver='sparse_cg')

# %%
y_pred = regg.predict(X_test)
print(f"R2 score: {r2_score(y_test, y_pred)}")
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score: 0.4625010162105878
# [  47.84104076 -160.12329735  368.68085558  273.55380011   -7.12516643
#   -58.21970104 -167.70918484  136.65943282  329.38091988   95.02343372]
# [141.96158435]

# %%
class MeraReg:

    def __init__(self, alpha, learning_rate, epochs):
        self.alpha = alpha
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.coef_ = None
        self.intercept_ = None

    def fit(self, X_train, y_train):
        self.coef_ = np.ones(X_train.shape[1])
        self.intercept_ = 0
        theta = np.insert(self.coef_ , 0, self.intercept_)

        X_train = np.insert(X_train, 0, 1, axis = 1)

        for i in range(self.epochs):
            theta_der = np.dot(X_train.T, X_train).dot(theta) - np.dot(X_train.T, y_train) + self.alpha *theta
            theta = theta - self.learning_rate * theta_der

        self.coef_ = theta[1:]
        self.intercept_ = theta[0]

    def predict(self, X_test):
        return np.dot(X_test, self.coef_) + self.intercept_

# %%
reg = MeraReg(alpha = 0.001, learning_rate = 0.005, epochs = 500)

# %%
reg.fit(X_train, y_train)

# %%
y_pred = reg.predict(X_test)
print(f"R2 score: {r2_score(y_test, y_pred)}")
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score: 0.47380182802609117
# [  46.65050914 -221.3750037   452.12080647  325.54248128  -29.09464178
#   -96.47517735 -190.90017011  146.32900372  400.80267299   95.09048094]
# 150.86975316713466
