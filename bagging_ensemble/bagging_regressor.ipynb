# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df = datasets.load_diabetes()
X, Y = df.data, df.target
print(f"Dataset Feature name: {str(df.feature_names)}")
print(f"Dataset feature size: {str(df.data.shape)}")
print(f"Dataset target size: {str(df.target.shape)}")
# Out:
# Dataset Feature name: ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Dataset feature size: (442, 10)
# Dataset target size: (442,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=123)

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
knn = KNeighborsRegressor()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = dt.predict(X_test)
y_pred3 = knn.predict(X_test)

# %%
print(f"R2 score of LR: {r2_score(y_test, y_pred1)}")
print(f"R2 score of DTR: {r2_score(y_test, y_pred2)}")
print(f"R2 score of KNR: {r2_score(y_test, y_pred3)}")
# Out:
# R2 score of LR: 0.5675895725793205
# R2 score of DTR: 0.19484928810583846
# R2 score of KNR: 0.438839665879189

# %%
bag = BaggingRegressor(random_state=1)
bag.fit(X_train, y_train)
# Out:
# BaggingRegressor(random_state=1)

# %%
y_pred = bag.predict(X_test)

# %%
print(f"Training coefficient of R2: {bag.score(X_train, y_train)}")
print(f"Testing coefficient of R2: {bag.score(X_test, y_test)}")
# Out:
# Training coefficient of R2: 0.8968084151942686
# Testing coefficient of R2: 0.49906647645203195

# %%
# %%time

params = {
    'estimator': [None, LinearRegression(), KNeighborsRegressor()],
    'n_estimators': [20, 50, 100],
    'max_samples': [0.5, 1.0],
    'max_features': [0.5, 1.0],
    'bootstrap': [True, False],
    'bootstrap_features': [True, False]
}

bagging_regressor_grid = GridSearchCV(BaggingRegressor(random_state=1, n_jobs=-1), param_grid=params,  cv=3, n_jobs=-1, verbose=1)
bagging_regressor_grid.fit(X_train, y_train)

print('Train R^2 Score : %.3f'%bagging_regressor_grid.best_estimator_.score(X_train, y_train))
print('Test R^2 Score : %.3f'%bagging_regressor_grid.best_estimator_.score(X_test, y_test))
print('Best R^2 Score Through Grid Search : %.3f'%bagging_regressor_grid.best_score_)
print('Best Parameters : ',bagging_regressor_grid.best_params_)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# Train R^2 Score : 0.487
# Test R^2 Score : 0.533
# Best R^2 Score Through Grid Search : 0.446
# Best Parameters :  {'bootstrap': False, 'bootstrap_features': True, 'estimator': LinearRegression(), 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 100}
# CPU times: total: 2.52 s
# Wall time: 50.7 s
